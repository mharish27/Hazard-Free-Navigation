# %%
import pandas as pd
from sklearn.cluster import MiniBatchKMeans

import warnings
warnings.filterwarnings("ignore")

# %%
# Load your data
path = 'train.csv'

data = pd.read_csv(path)

# %%
# Drop rows with missing or invalid coordinates
data.dropna(subset=['Latitude', 'Longitude'], inplace=True)

# %%
print(data.shape)
# Out:
# (878049, 9)

# %%
# Selecting only the latitude and longitude columns
geo_data = data[['Latitude', 'Longitude']]

# %%
print(geo_data.shape)
# Out:
# (878049, 2)

# %%
# Create the MiniBatch K-Means model
n_clusters = 200
kmeans = MiniBatchKMeans(n_clusters=n_clusters, batch_size=10000, random_state=0)

# %%
# Fit the model
kmeans.fit(geo_data)
# Out:
# MiniBatchKMeans(batch_size=10000, n_clusters=200, random_state=0)

# %%
# Extract cluster centers (hotspots)
hotspots = kmeans.cluster_centers_

# %%
# Convert hotspots to a DataFrame
hotspots_df = pd.DataFrame(hotspots, columns=['Latitude', 'Longitude'])

hotspots_df.head()
# Out:
#     Latitude   Longitude
# 0  37.732583 -122.447601
# 1  37.710541 -122.429040
# 2  37.783191 -122.410084
# 3  37.733936 -122.390471
# 4  37.767931 -122.457551

# %%
# Save the hotspots to a new CSV file
hotspots_df.to_csv('hotspots.csv', index=False)

# %%
import folium
from folium.plugins import HeatMap
import pandas as pd

# %%
# Load hotspots data
hotspots = pd.read_csv('hotspots.csv')

hotspots.head()
# Out:
#     Latitude   Longitude
# 0  37.732583 -122.447601
# 1  37.710541 -122.429040
# 2  37.783191 -122.410084
# 3  37.733936 -122.390471
# 4  37.767931 -122.457551

# %%
# Create a map centered around the mean location of the hotspots
map_center = [hotspots['Latitude'].mean(), hotspots['Longitude'].mean()]
map = folium.Map(location=map_center, zoom_start=12)

# %%
# Add hotspots to the map
for index, row in hotspots.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup='Hotspot',
        icon=folium.Icon(color='red')
    ).add_to(map)

# %%
# Display the map in Jupyter Notebook
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bdec0f941137c687469edbf27fe7cebc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bdec0f941137c687469edbf27fe7cebc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bdec0f941137c687469edbf27fe7cebc = L.map(
#                 &quot;map_bdec0f941137c687469edbf27fe7cebc&quot;,
#                 {
#                     center: [37.77697458693552, -122.43088014829493],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e5dcf1592b9e07d53ffba1d23de5e6f9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_e5dcf1592b9e07d53ffba1d23de5e6f9.addTo(map_bdec0f941137c687469edbf27fe7cebc);
#
#             var marker_89f07bd68578e4b3ec84435b2135000f = L.marker(
#                 [37.73258329515529, -122.44760112052845],
#                 {}
#             ).addTo(map_bdec0f941137c687469edbf27fe7cebc);
#
#
#             var icon_29e7c8fe5c889dddaa14c23b701bccaf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_89f07bd68578e4b3ec84435b2135000f.setIcon(icon_29e7c8fe5c889dddaa14c23b701bccaf);
#
#
#         var popup_6b6be04da8a7e8e5e3a68bf35a889e27 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_500d7dc8bb292812aafe835a37e73f72 = $(`&lt;div id=&quot;html_500d7dc8bb292812aafe835a37e73f72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hotspot&lt;/div&gt;`)[0];
#                 popup_6b6be04da8a7e8e5e3a68bf35a889e27.setContent(html_500d7dc8bb292812aafe835a37e73f72);
#
#
#
#         marker_89f07bd68578e4b3ec84435b2135000f.bindPopup(popup_6b6be04da8a7e8e5e3a68bf35a889e27)
#         ;
#
#
#
#
#             var marker_5240a8d5e844be2a39df82ff886efbc9 = L.marker(
#                 [37.710540816744555, -122.4290402052705],
#                 {}
#             ).addTo(map_bdec0f941137c687469edbf27fe7cebc);
#
#
#             var icon_021d52b70205de1af317062cef354f64 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5240a8d5e844be2a39df82ff886efbc9.setIcon(icon_021d52b70205de1af317062cef354f64);
#
#
#         var popup_775782f200899c514b17c7e160d5d4fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b2c1eef5ad1895a4d30f3f11afb697d = $(`&lt;div id=&quot;html_6b2c1eef5ad1895a4d30f3f11afb697d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hotspot&lt;/div&gt;`)[0];
#                 popup_775782f200899c514b17c7e160d5d4fd.setContent(html_6b2c1eef5ad1895a4d30f3f11afb697d);
#
#
#
#         marker_5240a8d5e844be2a39df82ff886efbc9.bindPopup(popup_775782f200899c514b17c7e160d5d4fd)
#         ;
#
#
#
#
#             var marker_9946212c4c8a0dfb3d389c505797a015 = L.marker(
#                 [37.78319083189445, -122.41008383799264],
#                 {}
#             ).addTo(map_bdec0f941137c687469edbf27fe7cebc);
#
#
#             var icon_62de0dcfbc00ddd27e98187b7417d567 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9946212c4c8a0dfb3d389c505797a015.setIcon(icon_62de0dcfbc00ddd27e98187b7417d567);
#
#
#         var popup_3bf50f3f36badb237b64414b959e184a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8d2b1411658e765e434982c50001d014 = $(`&lt;div id=&quot;html_8d2b1411658e765e434982c50001d014&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hotspot&lt;/div&gt;`)[0];
#                 popup_3bf50f3f36badb237b64414b959e184a.setContent(html_8d2b1411658e765e434982c50001d014);
#
#
#
#         marker_9946212c4c8a0dfb3d389c505797a015.bindPopup(popup_3bf50f3f36badb237b64414b959e184a)
#         ;
#
#
#
#
#             var marker_2b32f66ad60c7ee3f5eec3a6ba7058b8 = L.marker(
#                 [37.73393581276063, -122.39047075343292],
#                 {}
#             ).addTo(map_bdec0f941137c687469edbf27fe7cebc);
#
#
#             var icon_d73521ea7e8db19ee2

# %%
# Or save the map to an HTML file
# map.save('hotspots_map.html')
